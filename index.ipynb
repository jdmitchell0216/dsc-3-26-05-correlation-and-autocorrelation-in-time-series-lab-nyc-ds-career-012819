# %% [markdown]
# # Correlation and Autocorrelation in Time Series - Lab

# %% [markdown]
# ## Introduction
#
# In this lab, You'll practice your knowledge on correlation, autocorrelation and the ACF and PACF.

# %% [markdown]
# ## Objectives
#
# You will be able to:
# - Understand correlation in Time Series
# - Plot and discuss the autocorrelation function (ACF) for a time-series
# - Plot and discuss the partial autocorrelation function (PACF) for a time-series
# - Interpret ACF and PACF and Identify use cases both functions

# %% [markdown]
# ## The Exchange Rate Data

# %% [markdown]
# We'll be looking at the exchange rates dataset again. First, import the necessary libraries for time series and plotting. Then import the data (in `exch_rates.csv`) and make sure it's set in the correct time series format with the `datetime` as the index.

# %%
# your code here
import numpy as np, pandas as pd, matplotlib.pyplot as plt, statsmodels
from statsmodels.graphics.tsaplots import plot_pacf, plot_acf

# %%
# your code here
df = pd.read_csv('exch_rates.csv')

df['Frequency'] = pd.to_datetime(df['Frequency'])
df.set_index('Frequency', inplace=True)

# %% [markdown]
# Plot the three exchange rates in one plot

# %%
# your code here
df.plot(figsize=(15,7))

# %% [markdown]
# You can see that the EUR/USD and AUD/USD exchange rate are somewhere between rougly 0.5 and 2 between 2000 and 2018, where the Danish Krone is somewhere between roughly 4.5 and 9. Now let's look at the correlations between these time series.

# %%
# your code here
df.corr()
# Out:
#                        Euro  Australian Dollar  Danish Krone
# Euro               1.000000           0.883181      0.999952
# Australian Dollar  0.883181           1.000000      0.882513
# Danish Krone       0.999952           0.882513      1.000000

# %% [markdown]
# ### What is your conclusion here? You might want to use outside resources to understand what's going on.

# %% [markdown]
# Next, look at the plots of the differenced series. Use subplots to plot them rather than creating just one plot.

# %%
# your code here
df.diff(periods=1).plot(subplots=True, figsize=(15,7))
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x7f09995c84e0>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7f09995fac18>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7f09995ac0b8>],
#       dtype=object)

# %%
# your code here

# %%
# your code here

# %% [markdown]
# ### Explain what's going on

# %% [markdown]
# Next, let's look at the "lag 1 autocorrelation" for the EUR/USD exchange rate. Create a "lag 1 autocorrelation" series, plot the result, and look at the correlation coefficient.

# %%
euro_1
# Out:
# Frequency
# 2000-01-01         NaN
# 2000-01-02         NaN
# 2000-01-03         NaN
# 2000-01-04   -0.020677
# 2000-01-05   -0.005897
# 2000-01-06   -0.001857
# 2000-01-07    0.009735
# 2000-01-08         NaN
# 2000-01-09         NaN
# 2000-01-10         NaN
# 2000-01-11   -0.002574
# 2000-01-12   -0.004919
# 2000-01-13    0.003021
# 2000-01-14    0.004854
# 2000-01-15         NaN
# 2000-01-16         NaN
# 2000-01-17         NaN
# 2000-01-18    0.000098
# 2000-01-19   -0.001177
# 2000-01-20    0.001570
# 2000-01-21   -0.000786
# 2000-01-22         NaN
# 2000-01-23         NaN
# 2000-01-24         NaN
# 2000-01-25    0.001894
# 2000-01-26   -0.001097
# 2000-01-27    0.004302
# 2000-01-28    0.013029
# 2000-01-29         NaN
# 2000-01-30         NaN
#                 ...
# 2018-10-28         NaN
# 2018-10-29         NaN
# 2018-10-30    0.000696
# 2018-10-31    0.004195
# 2018-11-01   -0.005816
# 2018-11-02   -0.001845
# 2018-11-03         NaN
# 2018-11-04         NaN
# 2018-11-05         NaN
# 2018-11-06   -0.004463
# 2018-11-07   -0.004495
# 2018-11-08    0.004801
# 2018-11-09    0.006018
# 2018-11-10         NaN
# 2018-11-11         NaN
# 2018-11-12         NaN
# 2018-11-13    0.000316
# 2018-11-14   -0.002752
# 2018-11-15   -0.000705
# 2018-11-16   -0.003196
# 2018-11-17         NaN
# 2018-11-18         NaN
# 2018-11-19         NaN
# 2018-11-20    0.000460
# 2018-11-21    0.000921
# 2018-11-22    0.000461
# 2018-11-23    0.003940
# 2018-11-24         NaN
# 2018-11-25         NaN
# 2018-11-26         NaN
# Name: Euro, Length: 6905, dtype: float64

# %%
# your code here
euro_1 = df.Euro.diff(periods=1)
lag_1= pd.concat([euro_1, df.Euro], axis=1)
lag_1.plot(figsize=(15,7), alpha=0.5);

# %%
# your code here

# %%
# your code here

# %% [markdown]
# Repeat this, but for a "lag 5 autocorrelation"

# %%
# your code here

# %%
# your code here

# %% [markdown]
# ### What's your conclusion here?

# %% [markdown]
# Knowing this, let's plot the ACF now.

# %%
# your code here

# %% [markdown]
# The series is heavily autocorrelated at first, and then there is a decay. This is a typical result for a series that is a random walk, generally you'll see heavy autocorrelations first, slowly tailing off until there is no autocorrelation anymore.

# %% [markdown]
# Next, let's look at the Partial Autocorrelation Function.

# %%
# your code here

# %% [markdown]
# This is interesting! Remember that *Partial Autocorrelation Function* gives the partial correlation of a time series with its own lagged values, controlling for the values of the time series at all shorter lags. When controlling for 1 period lags, the PACF is only very high for one-period lags, and basically 0 for shorter lags. This is again a typical result for Random Walk series!

# %% [markdown]
# ## The Airpassenger Data

# %% [markdown]
# Look at ACF and PACF for the airpassenger data and describe the result `passengers.csv`. Do this both for the differenced and regular series.

# %%
# your code here

# %%
# your code here

# %%
# your code here

# %%
# your code here

# %%
# your code here

# %%
# your code here

# %%
# your code here

# %% [markdown]
# ### Your conclusion here

# %% [markdown]
# ## The NYSE data

# %% [markdown]
# Look at correlation and autocorrelation functions for the NYSE data ("NYSE_monthly.csv")

# %%
# your code here

# %%
# your code here

# %%
# your code here

# %% [markdown]
# ## Your conclusion here

# %% [markdown]
# ## Summary
#
# Great, you've now been introduced to correlation, the ACF and PACF. Let's move into more serious modeling with autoregressive and moving average models!
